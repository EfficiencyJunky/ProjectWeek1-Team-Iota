# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import seaborn as sb

# %%
# File to Load (Remember to change these)
OWID_literacy_csv_path = "cross-country-literacy-rates.csv"

# Read in the data from the CSV
OWID_literacy_data = pd.read_csv(OWID_literacy_csv_path)

# convert data to a DataFrame
OWID_literacy_df_raw = pd.DataFrame(OWID_literacy_data)
OWID_literacy_df = OWID_literacy_df_raw.rename(columns={"Life expectancy (Clio-Infra up to 1949; UN Population Division for 1950 to 2015) (years)":"Life expectancy"})
OWID_literacy_df["Entity"].value_counts()
# Out:
# Nicaragua                    39
# Honduras                     35
# Colombia                     31
# Ecuador                      30
# Paraguay                     27
# Costa Rica                   25
# Uruguay                      25
# Dominican Republic           25
# Venezuela                    25
# Mexico                       25
# Guatemala                    23
# Haiti                        23
# El Salvador                  23
# Bolivia                      22
# Panama                       22
# Cuba                         22
# Brazil                       21
# Spain                        19
# Peru                         19
# Chile                        18
# Turkey                       15
# United States                15
# Argentina                    14
# World                        14
# Palestine                    12
# Qatar                        12
# Iran                         11
# Kuwait                       11
# Pakistan                     11
# ...

# %%
usa_stats = OWID_literacy_df.loc[OWID_literacy_df["Entity"] == "United States",:]
usa_stats
# Out:
#              Entity Code  Year  \
# 1308  United States  USA  1870
# 1309  United States  USA  1880
# 1310  United States  USA  1890
# 1311  United States  USA  1900
# 1312  United States  USA  1910
# 1313  United States  USA  1920
# 1314  United States  USA  1930
# 1315  United States  USA  1940
# 1316  United States  USA  1947
# 1317  United States  USA  1950
# 1318  United States  USA  1952
# 1319  United States  USA  1959
# 1320  United States  USA  1969
# 1321  United States  USA  1979
# 1322  United States  USA  2003
#
#       Literacy rates (World Bank, CIA World Factbook, and other sources) (%)
# 1308                                          80.000000
# 1309                                          83.000000
# 1310                                          86.699997
# 1311                                          89.300003
# 1312                                          92.300003
# 1313                                          94.000000
# ...

# %%
categories_of_literacy = OWID_literacy_df.loc[OWID_literacy_df["Code"].isnull() == False,:]
categories_of_literacy["Entity"].value_counts()
categories_of_literacy.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1979
# 1  Afghanistan  AFG  2011
# 2  Afghanistan  AFG  2015
# 3      Albania  ALB  2001
# 4      Albania  ALB  2008
#
#    Literacy rates (World Bank, CIA World Factbook, and other sources) (%)
# 0                                          18.157681
# 1                                          31.741119
# 2                                          38.168041
# 3                                          98.712982
# 4                                          95.938637

# %%
x_axis = categories_of_literacy["Year"].unique()
x_axis.sort()
x_axis
# Out:
# array([1475, 1550, 1650, 1750, 1820, 1870, 1880, 1890, 1900, 1910, 1920,
#        1930, 1940, 1947, 1950, 1952, 1959, 1960, 1969, 1970, 1971, 1972,
#        1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])

# %%
# create initial plot
#fig, ax = plt.subplots()
high_income_life_ex = continental_life_expectancy.loc[OWID_life_expectancy_df["Entity"] == "High-income countries",:]
upper_middle_income_life_ex = OWID_life_expectancy_df.loc[OWID_life_expectancy_df["Entity"] == "Upper-middle-income countries",:]
middle_income_life_ex = OWID_life_expectancy_df.loc[OWID_life_expectancy_df["Entity"] == "Middle-income countries",:]
lower_middle_income_life_ex = OWID_life_expectancy_df.loc[OWID_life_expectancy_df["Entity"] == "Lower-middle-income countries",:]
low_income_life_ex = OWID_life_expectancy_df.loc[OWID_life_expectancy_df["Entity"] == "Low-income countries",:]

#print(low_income_life_ex)

# Create a handle for each plot
# 
a_handle = plt.plot(x_axis, high_income_life_ex["Life expectancy"], label="High")
b_handle = plt.plot(x_axis, upper_middle_income_life_ex["Life expectancy"], label="Upper Middle")
c_handle = plt.plot(x_axis, middle_income_life_ex["Life expectancy"], label="Middle")
d_handle = plt.plot(x_axis, lower_middle_income_life_ex["Life expectancy"], label="Lower Middle")
e_handle = plt.plot(x_axis, low_income_life_ex["Life expectancy"], label="Low")

plt.title("Avg Life Expectancy by Income Level")
plt.xlabel("Year")
plt.ylabel("Avg. Life Expectancy")

plt.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="640">
